# %% [markdown]
# <a href="https://colab.research.google.com/github/EddiRafael/Extraccion-de-datos/blob/main/Entregable1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#cargar archivo csv desde equipo 
from google.colab import files 
files.upload()

# %%
#convertir en dataframe 
df= pd.read_csv("CountryTable.csv")
df
# Out:
#     code          name      continent                     region  \
# 0    ABW         Aruba  North America                  Caribbean
# 1    AFG   Afghanistan           Asia  Southern and Central Asia
# 2    AGO        Angola         Africa             Central Africa
# 3    AIA      Anguilla  North America                  Caribbean
# 4    ALB       Albania         Europe            Southern Europe
# ..   ...           ...            ...                        ...
# 234  YEM         Yemen           Asia                Middle East
# 235  YuG    Yugoslavia         Europe            Southern Europe
# 236  ZAF  South Africa         Africa            Southern Africa
# 237  ZMB        Zambia         Africa             Eastern Africa
# 238  ZWE      Zimbabwe         Africa             Eastern Africa
#
#      surface_area  independence_year  population  life_expectancy       gnp  \
# 0           193.0                NaN      103000             78.4     828.0
# ...

# %%
#filtro por objeto filtro 1 ejemplo 1 
filtro1a=df[df["continent"]=="Africa"]
filtro1a
# Out:
#     code                                   name continent           region  \
# 2    AGO                                 Angola    Africa   Central Africa
# 17   BDI                                Burundi    Africa   Eastern Africa
# 19   BEN                                  Benin    Africa   Western Africa
# 20   BFA                           Burkina Faso    Africa   Western Africa
# 35   BWA                               Botswana    Africa  Southern Africa
# 36   CAF               Central African Republic    Africa   Central Africa
# 42   CIV                           Cote dIvoire    Africa   Western Africa
# 43   CMR                               Cameroon    Africa   Central Africa
# 44   COD  Congo, The Democratic Republic of the    Africa   Central Africa
# 45   COG                                  Congo    Africa   Central Africa
# 48   COM                                Comoros    Africa   Eastern Africa
# ...

# %%
#convertir archivo filtrado a csv
filtro1a.to_csv("filtro1 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro1 ejemplo 1.csv")

# %%
#filtro 1 ejemplo 2
filtro1b=df[df["region"]=="Caribbean"]
filtro1b
# Out:
#     code                              name      continent     region  \
# 0    ABW                             Aruba  North America  Caribbean
# 3    AIA                          Anguilla  North America  Caribbean
# 6    ANT              Netherlands Antilles  North America  Caribbean
# 13   ATG               Antigua and Barbuda  North America  Caribbean
# 24   BHS                           Bahamas  North America  Caribbean
# 31   BRB                          Barbados  North America  Caribbean
# 51   CuB                              Cuba  North America  Caribbean
# 53   CYM                    Cayman Islands  North America  Caribbean
# 58   DMA                          Dominica  North America  Caribbean
# 60   DOM                Dominican Republic  North America  Caribbean
# 81   GLP                        Guadeloupe  North America  Caribbean
# 86   GRD                           Grenada  North America  Caribbean
# 96   HTI                             Haiti  North America  Caribbean
# ...

# %%
#convertir archivo filtrado a csv
filtro1a.to_csv("filtro1 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro1 ejemplo 2.csv")

# %%
#filtro 2 ejemplo 1 filas 
filtro2a= df.iloc[50:100,: ]
filtro2a

# %%
#convertir archivo filtrado a csv
filtro2a.to_csv("filtro2 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro2 ejemplo 1.csv")

# %%
#filtro 2 ejemplo 2
filtro2b= df.iloc[[100, 200, 238], : ]
filtro2b

# %%
#convertir archivo filtrado a csv
filtro2b.to_csv("filtro2 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro2 ejemplo 2.csv")

# %%
#filtro 3 ejemplo 1 columnas 
filtro3a= df.iloc[ : , 4:6]
filtro3a

# %%
#convertir archivo filtrado a csv
filtro3a.to_csv("filtro3 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro3 ejemplo 1.csv")

# %%
#filtro 3 ejemplo 2
filtro3b= df.iloc[ : , [1,4,6]]
filtro3b

# %%
#convertir archivo filtrado a csv
filtro3b.to_csv("filtro3 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro3 ejemplo 2.csv")

# %%
#filtro 4 ejemplo 1 columnas y filas 
filtro4a= df.iloc[ [10,20,50] , 2:5]
filtro4a
# Out:
#         continent           region  surface_area
# 10        Oceania        Polynesia         199.0
# 20         Africa   Western Africa      274000.0
# 50  North America  Central America       51100.0

# %%
#convertir archivo filtrado a csv
filtro4a.to_csv("filtro4 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro4 ejemplo 1.csv")

# %%
#filtro 4 ejemplo 2
filtro4b= df.iloc[ [5,15,30] , 3:8]
filtro4b
# Out:
#              region  surface_area  independence_year  population  \
# 5   Southern Europe         468.0             1278.0       78000
# 15   Western Europe       83859.0             1918.0     8091800
# 30    South America     8547403.0             1822.0   170115000
#
#     life_expectancy
# 5              83.5
# 15             77.7
# 30             62.9

# %%
#convertir archivo filtrado a csv
filtro4b.to_csv("filtro4 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro4 ejemplo 2.csv")

# %%
#filtro 5 filtro por cabecera
filtro5a= df.head()
filtro5a
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %%
#convertir archivo filtrado a csv
filtro5a.to_csv("filtro5 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro5 ejemplo 1.csv")

# %%
#filtro 5 ejemplo 2
filtro5b= df.head(3)
filtro5b
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
#
#               local_name                               government_form  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
# 2                 Angola                                      Republic
#
#              head_of_state  capital code2
# 0         Willem-Alexander    129.0    AW
# ...

# %%
#convertir archivo filtrado a csv
filtro5b.to_csv("filtro5 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro5 ejemplo 2.csv")

# %%
#filtro 6 filtro por comparacion 
filtro6a= df[df["independence_year"] > 1970]
filtro6a

# %%
#convertir archivo filtrado a csv
filtro6a.to_csv("filtro6 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro6 ejemplo 1.csv")

# %%
#filtro 6 ejemplo 2
filtro6b= df[df["life_expectancy"] < 70]
filtro6b

# %%
#convertir archivo filtrado a csv
filtro6b.to_csv("filtro6 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro6 ejemplo 2.csv")

# %%
#filtro 7 filtro &
filtro7a= df[(df["continent"] == "Asia") & (df["region"]== "Middle East")]
filtro7a

# %%
#convertir archivo filtrado a csv
filtro7a.to_csv("filtro7 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro7 ejemplo 1.csv")

# %%
#filtro 7 ejemplo 2
filtro7b= df[(df["continent"] == "Europe") & (df["region"]== "Southern Europe")]
filtro7b

# %%
#convertir archivo filtrado a csv
filtro7b.to_csv("filtro7 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro7 ejemplo 2.csv")

# %%
#filtro 8 filtro o
filtro8a= df[(df["continent"]== "Europe") | (df["independence_year"]> 1800)]
filtro8a

# %%
#convertir archivo filtrado a csv
filtro8a.to_csv("filtro8 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro8 ejemplo 1.csv")

# %%
#filtro 8 ejemplo 2
filtro8b= df[(df["continent"]== "North America") | (df["independence_year"]< 1900)]
filtro8b

# %%
#convertir archivo filtrado a csv
filtro8b.to_csv("filtro8 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro8 ejemplo 2.csv")

# %%
#filtro 9 filtro not 
filtro9a= df[~(df["continent"] == "Africa") & ~(df["independence_year"] <1855)]
filtro9a

# %%
#convertir archivo filtrado a csv
filtro9a.to_csv("filtro9 ejemplo 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro9 ejemplo 1.csv")

# %%
#filtro 9 ejemplo 2
filtro9b= df[~(df["region"] == "Caribbean") & ~(df["surface_area"] <1000)]
filtro9b

# %%
#convertir archivo filtrado a csv
filtro9b.to_csv("filtro9 ejemplo 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("filtro9 ejemplo 2.csv")
